# %%
import os

# %%
os.listdir('/content')
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## **What do we plan to do here?**
# * I have been victim of horrible Bangalore traffic!
# * Ask any Bangalorean and he/she will have a heart wrenching story to tell
# * While doing some research I came across [this](https://www.deccanherald.com/content/643687/study-reveals-bengaluru-residents-spend.html) interesting article which quantifies the average time Bangaloreans take to commute to office
# * This triggered this thought, can I analyze my own travel data and develop some cool insights

# %% [markdown]
# ## **Steps to be followed :**
# * Read my location data (pulled from my google account) as json
# * Devise a mechanism to find distance between my home and office
# * Do exploratory data analysis to find clogged points

# %%
import json

# %%
data = '{
  "locations" : [ {
    "timestampMs" : "1516589350178",
    "latitudeE7" : 295642474,
    "longitudeE7" : -985932226,
    "accuracy" : 1000,
    "activity" : [ {
      "timestampMs" : "1516589383476",
      "activity" : [ {
        "type" : "IN_VEHICLE",
        "confidence" : 89
      }, {
        "type" : "IN_ROAD_VEHICLE",
        "confidence" : 89
      }, {
        "type" : "STILL",
        "confidence" : 4
      }, {
        "type" : "IN_RAIL_VEHICLE",
        "confidence" : 3
      }, {
        "type" : "UNKNOWN",
        "confidence" : 2
      }, {
        "type" : "ON_FOOT",
        "confidence" : 1
      }, {
        "type" : "WALKING",
        "confidence" : 1
      }, {
        "type" : "ON_BICYCLE",
        "confidence" : 0
      } ]
    } ]
  }]
}'

# %%
type(data)
# Out:
# dict

# %%
person_dict = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8cdfbd9a11c6> in <module>()
# ----> 1 person_dict = json.loads(data)
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
f = open('data.json',)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-3229130d06a6> in <module>()
# ----> 1 f = open('data.json',)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.json'

# %%
json_string
# Out:
# '"data.json"'

# %%
x = json.load(json_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-636d454325c0> in <module>()
# ----> 1 x = json.load(json_string)
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
type(x)
# Out:
# str
